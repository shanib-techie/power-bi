# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("C:\\Users\\Admin\\OneDrive\\Desktop\\power bi\\retail_store_analysis\\Retail-Store-Transactions (1).xlsx")


df.drop(columns = ["Unnamed: 17"], inplace = True)
# df.drop(columns= ["bonus"], inplace = True)
df = df.loc[:, ~df.columns.str.contains("^Unnamed")]
print(df.head(4))

# df.drop("Unnamed: 14")
# Out:
#     time StoreID Location  Product  Quantity PaymentType TransactionID  \
# 0  15:29      S3  Store C   Tablet         3   Gift Card      TX300000
# 1  16:53      S1  Store B  Printer         9      Online      TX300001
# 2  21:22      S9  Store B   Laptop         9  Debit Card      TX300002
# 3  14:28      S9  Store C  Monitor         7      Online      TX300003
#
#   Cashier StoreManager  TimeOfDay DayOfWeek  TotalPrice  per unit
# 0      C1         Noah  Afternoon  Saturday     1092.66    364.22
# 1      C5         Liam  Afternoon  Thursday     3462.66    384.74
# 2      C3         Liam    Evening    Friday     3580.20    397.80
# 3      C2          Mia  Afternoon  Saturday      561.89     80.27

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("C:\\Users\\Admin\\OneDrive\\Desktop\\power bi\\retail_store_analysis\\Retail-Store-Transactions (1).xlsx")


print("how much time each product sell",df["Product"].value_counts())
print(df["Product"].unique())
print("how much time each location come",df["Location"].value_counts())
print(df["Location"].unique())
print("how much time store manager sales",df["StoreManager"].value_counts())
print(df["StoreManager"].unique())
print("cashier",df["Cashier"].unique())
print(df["Cashier"].value_counts())
# print(max(df["TotalPrice"]))
# Out:
# how much time each product sell Product
# Phone      38
# Desk       31
# Monitor    30
# Printer    29
# Laptop     28
# Chair      25
# Tablet     18
# Name: count, dtype: int64
# <StringArray>
# ['Tablet', 'Printer', 'Laptop', 'Monitor', 'Desk', 'Chair', 'Phone']
# Length: 7, dtype: str
# how much time each location come Location
# Store C    64
# Store D    54
# Store B    41
# Store A    40
# Name: count, dtype: int64
# <StringArray>
# ['Store C', 'Store B', 'Store A', 'Store D']
# Length: 4, dtype: str
# how much time store manager sales StoreManager
# Noah      53
# Olivia    53
# Mia       47
# Liam      46
# Name: count, dtype: int64
# <StringArray>
# ['Noah', 'Liam', 'Mia', 'Olivia']
# Length: 4, dtype: str
# cashier <StringArray>
# ['C1', 'C5', 'C3', 'C2', 'C4']
# Length: 5, dtype: str
# Cashier
# C1    45
# C5    42
# C2    39
# C4    38
# C3    35
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("C:\\Users\\Admin\\OneDrive\\Desktop\\power bi\\retail_store_analysis\\Retail-Store-Transactions (1).xlsx")


# r_from_c = df[df["Location"] == "Store C"]["TotalPrice"].sum()
# print("total revenue from c store",r_from_c)


r_from_d = df[df["Location"] == "Store D"]["TotalPrice"].sum()
print("revenue from d location",r_from_d)


print("revenue from each location ")
r_each_l = df.groupby("Location")["TotalPrice"].sum()
print(r_each_l)
# Out:
# revenue from d location 54490.079999999994
# revenue from each location
# Location
# Store A    36979.24
# Store B    46201.25
# Store C    82529.80
# Store D    54490.08
# Name: TotalPrice, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("C:\\Users\\Admin\\OneDrive\\Desktop\\power bi\\retail_store_analysis\\Retail-Store-Transactions (1).xlsx")

r_each_l_graph = df.groupby("Location")["TotalPrice"].sum()
r_each_l_graph.plot(kind="bar")
plt.plot(r_each_l_graph)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("C:\\Users\\Admin\\OneDrive\\Desktop\\power bi\\retail_store_analysis\\Retail-Store-Transactions (1).xlsx")

tablet_revenue = df[df["Product"] == "Tablet"]["TotalPrice"].sum()
print("How much revenue from Tablet:", tablet_revenue)
printer_revenue = df[df["Product"] == "Printer"]["TotalPrice"].sum()
print("how much revenue from printer",printer_revenue)
phone_revenue = df[df["Product"] == "Phone"]["TotalPrice"].sum()
print("how much revenue from phone",phone_revenue)
monitor_revenue = df[df["Product"] == "Monitor"]["TotalPrice"].sum()
print("revenue from monitor ",monitor_revenue)
laptop_revenue = df[df["Product"] == "Laptop"]["TotalPrice"].sum()
print("revenue from Laptop",laptop_revenue)
chair_revenue = df[df["Product"] == "Chair"]["TotalPrice"].sum()
print("revenue from chair ",chair_revenue)
desk_revenue = df[df["Product"] == "Desk"]["TotalPrice"].sum()
print("REvenue from desk",desk_revenue)
r_each_p = df.groupby("Product")["TotalPrice"].sum()
print("revenue of each product",r_each_p)
# Out:
# How much revenue from Tablet: 14153.64
# how much revenue from printer 37266.78
# how much revenue from phone 39972.88999999999
# revenue from monitor  39149.58999999999
# revenue from Laptop 34613.89
# revenue from chair  15524.54
# REvenue from desk 39519.04
# revenue of each product Product
# Chair      15524.54
# Desk       39519.04
# Laptop     34613.89
# Monitor    39149.59
# Phone      39972.89
# Printer    37266.78
# Tablet     14153.64
# Name: TotalPrice, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("C:\\Users\\Admin\\OneDrive\\Desktop\\power bi\\retail_store_analysis\\Retail-Store-Transactions (1).xlsx")

revenue = df.groupby(["Location", "Product"])["TotalPrice"].sum()#kaam ka function h

print("revenue from ech location with every product",revenue)
# Out:
# revenue from ech location with every product Location  Product
# Store A   Chair       2858.23
#           Desk        8818.22
#           Laptop      2582.69
#           Monitor     7547.09
#           Phone       7010.77
#           Printer     4771.71
#           Tablet      3390.53
# Store B   Chair       2747.07
#           Desk        3853.75
#           Laptop      8415.78
#           Monitor    14162.10
#           Phone       8600.25
#           Printer     8386.45
#           Tablet        35.85
# Store C   Chair       4272.22
#           Desk       14913.72
#           Laptop     18783.91
#           Monitor    12181.66
#           Phone      15128.90
#           Printer    11274.03
#           Tablet      5975.36
# Store D   Chair       5647.02
#           Desk       11933.35
#           Laptop      4831.51
#           Monitor     5258.74
#           Phone       9232.97
#           Printer    12834.59
#           Tablet      4751.90
# Name: TotalPrice, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("C:\\Users\\Admin\\OneDrive\\Desktop\\power bi\\retail_store_analysis\\Retail-Store-Transactions (1).xlsx")

# ANYLSIS ON  PaymentType
print("PAYMENT METHOD ==>",df["PaymentType"].unique())
print("count of payment method ")
print(df["PaymentType"].value_counts())
# kis loacation se kitne kitne payment type hue h 
loc_with_payment_type = df.groupby(["Location","PaymentType"])["TotalPrice"].sum()
print("each location with count of payment method ",loc_with_payment_type)

loc_with_payment_type_count = df.groupby(["Location","PaymentType"]).size()
print(loc_with_payment_type_count)
# Out:
# PAYMENT METHOD ==> <StringArray>
# ['Gift Card', 'Online', 'Debit Card', 'Cash', 'Credit Card']
# Length: 5, dtype: str
# count of payment method
# PaymentType
# Gift Card      49
# Debit Card     43
# Credit Card    43
# Online         35
# Cash           29
# Name: count, dtype: int64
# each location with count of payment method  Location  PaymentType
# Store A   Cash            5061.43
#           Credit Card     8652.11
#           Debit Card      4262.72
#           Gift Card      11578.21
#           Online          7424.77
# Store B   Cash            5474.19
#           Credit Card    15560.17
#           Debit Card      5966.22
#           Gift Card       9361.99
#           Online          9838.68
# Store C   Cash           14972.65
#           Credit Card    13460.35
#           Debit Card     16516.24
#           Gift Card      22492.41
#           Online         15088.15
# Store D   Cash            4464.85
#           Credit Card    13155.70
#           Debit Card     18778.94
#           Gift Card       9131.81
#           Online          8958.78
# Name: TotalPrice, dtype: float64
# Location  PaymentType
# Store A   Cash            6
#           Credit Card    11
#           Debit Card      9
#           Gift Card       9
#           Online          5
# Store B   Cash            6
#           Credit Card    12
#           Debit Card      6
#           Gift Card      10
#           Online          7
# Store C   Cash            9
#           Credit Card     8
#           Debit Card     14
#           Gift Card      18
#           Online         15
# Store D   Cash            8
#           Credit Card    12
#           Debit Card     14
#           Gift Card      12
#           Online          8
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("C:\\Users\\Admin\\OneDrive\\Desktop\\power bi\\retail_store_analysis\\Retail-Store-Transactions (1).xlsx")

loc_with_payment_type_count_make_graph = df.groupby(["Location","PaymentType"]).size().unstack()

loc_with_payment_type_count_make_graph.plot(kind="bar")

# plt.xlabel("Stores")
plt.ylabel("Count of Payment Type")
plt.title("Payment Type Count per Store")
plt.grid("-")

plt.legend(title="Payment Type")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("C:\\Users\\Admin\\OneDrive\\Desktop\\power bi\\retail_store_analysis\\Retail-Store-Transactions (1).xlsx")
# operation on store manager


storemanager_names = df["StoreManager"].unique()
print("NUMBER OF STORE MANAGER = > ",len(storemanager_names))
print("store manager = >",storemanager_names)

# # each store manager total sale 
print("each store manager total sale :")
val_of_each_store_manager = df["StoreManager"].value_counts()
print(val_of_each_store_manager)

print("DID CASHIER AND STORRE MANAGER ARE SAME ??")
grp_of_cashier_and_manager = df.groupby(["Cashier","StoreManager"]).size()
print(grp_of_cashier_and_manager)
# Out:
# NUMBER OF STORE MANAGER = >  4
# store manager = > <StringArray>
# ['Noah', 'Liam', 'Mia', 'Olivia']
# Length: 4, dtype: str
# each store manager total sale :
# StoreManager
# Noah      53
# Olivia    53
# Mia       47
# Liam      46
# Name: count, dtype: int64
# DID CASHIER AND STORRE MANAGER ARE SAME ??
# Cashier  StoreManager
# C1       Liam             9
#          Mia              9
#          Noah            12
#          Olivia          15
# C2       Liam             7
#          Mia              7
#          Noah            14
#          Olivia          11
# C3       Liam             9
#          Mia              7
#          Noah            10
#          Olivia           9
# C4       Liam             8
#          Mia             11
#          Noah            10
#          Olivia           9
# C5       Liam            13
#          Mia             13
#          Noah             7
#          Olivia           9
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("C:\\Users\\Admin\\OneDrive\\Desktop\\power bi\\retail_store_analysis\\Retail-Store-Transactions (1).xlsx")
grp_of_cashier_and_manager_graph = df.groupby(["Cashier","StoreManager"]).size().unstack()

grp_of_cashier_and_manager_graph.plot(kind="bar")
plt.title("cashier group with manager")
plt.grid("-")
plt.ylabel("count of cashier with differnet store manager ")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("C:\\Users\\Admin\\OneDrive\\Desktop\\power bi\\retail_store_analysis\\Retail-Store-Transactions (1).xlsx")
grp_of_manager_with_product = df.groupby(["StoreManager","Product"])["TotalPrice"].sum()

print("STORE MANAGER WITH HIS SALES IN EACH PRODUCT : ")
print(grp_of_manager_with_product)
# Out:
# STORE MANAGER WITH HIS SALES IN EACH PRODUCT :
# StoreManager  Product
# Liam          Chair       2074.82
#               Desk        8690.86
#               Laptop     10078.43
#               Monitor    11082.06
#               Phone       5904.85
#               Printer    10596.75
#               Tablet      2964.92
# Mia           Chair        894.19
#               Desk       12099.45
#               Laptop     10887.66
#               Monitor     6583.13
#               Phone      11788.55
#               Printer     8009.47
#               Tablet      5613.68
# Noah          Chair       6265.77
#               Desk       12241.22
#               Laptop     10751.26
#               Monitor     7819.56
#               Phone       9717.86
#               Printer     8645.40
#               Tablet      3915.62
# Olivia        Chair       6289.76
#               Desk        6487.51
#               Laptop      2896.54
#               Monitor    13664.84
#               Phone      12561.63
#               Printer    10015.16
#               Tablet      1659.42
# Name: TotalPrice, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("C:\\Users\\Admin\\OneDrive\\Desktop\\power bi\\retail_store_analysis\\Retail-Store-Transactions (1).xlsx")

summary = df.groupby("StoreManager").agg(
    Total_Sales=("TotalPrice", "sum"),
    Avg_Sale=("TotalPrice", "mean"),
    Number_of_Transactions=("TotalPrice", "count")
)

print(summary)
pivot = df.pivot_table(
    index="StoreManager",
    columns="Product",
    values="TotalPrice",
    aggfunc="sum",
    margins=True,
    margins_name="Total_All_Products"
)

print(pivot)
# Out:
#               Total_Sales     Avg_Sale  Number_of_Transactions
# StoreManager
# Liam             51392.69  1117.232391                      46
# Mia              55876.13  1188.853830                      47
# Noah             59356.69  1119.937547                      53
# Olivia           53574.86  1010.846415                      53
# Product                Chair      Desk    Laptop   Monitor     Phone  \
# StoreManager
# Liam                 2074.82   8690.86  10078.43  11082.06   5904.85
# Mia                   894.19  12099.45  10887.66   6583.13  11788.55
# Noah                 6265.77  12241.22  10751.26   7819.56   9717.86
# Olivia               6289.76   6487.51   2896.54  13664.84  12561.63
# Total_All_Products  15524.54  39519.04  34613.89  39149.59  39972.89
#
# Product              Printer    Tablet  Total_All_Products
# StoreManager
# Liam                10596.75   2964.92            51392.69
# Mia                  8009.47   5613.68            55876.13
# Noah                 8645.40   3915.62            59356.69
# Olivia              10015.16   1659.42            53574.86
# Total_All_Products  37266.78  14153.64           220200.37

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("C:\\Users\\Admin\\OneDrive\\Desktop\\power bi\\retail_store_analysis\\Retail-Store-Transactions (1).xlsx")

print(df["Cashier"].unique())
# GROUP GRAPH OF EACH STORE MANAGER PERTICULAR ITEM SALES
grp_of_manager_with_product_grap = df.groupby(["StoreManager" , "Product"])["TotalPrice"].sum().unstack()

grp_of_manager_with_product_grap.plot(kind = "bar")
plt.grid()
plt.xlabel("store manager ")
plt.show()
# Out:
# <StringArray>
# ['C1', 'C5', 'C3', 'C2', 'C4']
# Length: 5, dtype: str

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("C:\\Users\\Admin\\OneDrive\\Desktop\\power bi\\retail_store_analysis\\Retail-Store-Transactions (1).xlsx")
sale_by_manager_count = df.groupby(["StoreManager"])["TotalPrice"].size()
print(sale_by_manager_count)
sale_by_manager = df.groupby(["StoreManager"])["TotalPrice"].sum()
print(sale_by_manager)
plt.bar(val_of_each_store_manager.index,val_of_each_store_manager.values,color="yellow",label="store manager sales")
plt.xlabel("store manager")
plt.ylabel("store manager count of sales")
plt.show()
# Out:
# StoreManager
# Liam      46
# Mia       47
# Noah      53
# Olivia    53
# Name: TotalPrice, dtype: int64
# StoreManager
# Liam      51392.69
# Mia       55876.13
# Noah      59356.69
# Olivia    53574.86
# Name: TotalPrice, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("C:\\Users\\Admin\\OneDrive\\Desktop\\power bi\\retail_store_analysis\\Retail-Store-Transactions (1).xlsx")
# pie chart of store manager with its sale
sale_of_each_storemaneger = df.groupby(["StoreManager"])["TotalPrice"].sum()
print(sale_of_each_storemaneger)
plt.pie(sale_of_each_storemaneger,labels=sale_of_each_storemaneger.index,autopct="%1.1f%%",colors=["red","yellow","pink","green","blue"])#label  pie ki per seace ki valy
plt.grid()
plt.title("SALES OF EACH STORE MANAGER ")
plt.show()
# Out:
# StoreManager
# Liam      51392.69
# Mia       55876.13
# Noah      59356.69
# Olivia    53574.86
# Name: TotalPrice, dtype: float64
