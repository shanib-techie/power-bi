# %%
# Trader Performance vs Market Sentiment Analysis

## Objective
# To analyze how market sentiment (Fear/Greed) affects trader behavior and performance using Hyperliquid trading data.
# Out:
# working

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sentiment = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\power bi\\data science ]\\fear_greed_index.csv")
trades = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\power bi\\data science ]\\historical_data (1).csv")

sentiment.head()
trades.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sentiment = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\power bi\\data science ]\\fear_greed_index.csv")
#       2 trades = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\power bi\\data science ]\\historical_data (1).csv")
#       4 sentiment.head()
#
# NameError: name 'pd' is not defined

# %%
sentiment['date'] = pd.to_datetime(sentiment['date'], errors='coerce')

# sirf date part
sentiment['date'] = sentiment['date'].dt.date

sentiment.head()
# Out:
#     timestamp  value classification        date
# 0  1517463000     30           Fear  2018-02-01
# 1  1517549400     15   Extreme Fear  2018-02-02
# 2  1517635800     40           Fear  2018-02-03
# 3  1517722200     24   Extreme Fear  2018-02-04
# 4  1517808600     11   Extreme Fear  2018-02-05

# %%
trades.rename(columns={
    'account': 'account',
    'closed pnl': 'closedPnL',
    'side': 'side',
    'leverage': 'leverage'
}, inplace=True)

# %%
merged = pd.merge(trades, sentiment, on='date', how='inner')

merged.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15172\43015343.py in ?()
# ----> 1 merged = pd.merge(trades, sentiment, on='date', how='inner')
#       2
#       3 merged.head()
#
# c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     381             indicator=indicator,
#     382             validate=validate,
#     383         )
#     384     else:
# --> 385         op = _MergeOperation(
#     386             left_df,
#     387             right_df,
#     388             how=how,
#
# c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#    1014             self.right_join_keys,
#    1015             self.join_names,
#    1016             left_drop,
#    1017             right_drop,
# -> 1018         ) = self._get_merge_keys()
#    1019
#    1020         if left_drop:
#    1021             self.left = self.left._drop_labels_or_levels(left_drop)
#
# c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\merge.py in ?(self)
#    1629                     if lk is not None:
#    1630                         # Then we're either Hashable or a wrong-length arraylike,
#    1631                         #  the latter of which will raise
#    1632                         lk = cast(Hashable, lk)
# -> 1633                         left_keys.append(left._get_label_or_level_values(lk))
#    1634                         join_names.append(lk)
#    1635                     else:
#    1636                         # work-around for merge_asof(left_index=True)
#
# c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1772             values = self.xs(key, axis=first_other_axes)._values
#    1773         elif self._is_level_reference(key, axis=axis):
#    1774             values = self.axes[axis].get_level_values(key)._values
#    1775         else:
# -> 1776             raise KeyError(key)
#    1777
#    1778         # Check for duplicates
#    1779         if values.ndim > 1:
#
# KeyError: 'date'

# %%
trades['timestamp ist'] = pd.to_datetime(trades['timestamp ist'], dayfirst=True, errors='coerce')

trades['date'] = trades['timestamp ist'].dt.date

trades.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'timestamp ist'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 trades['timestamp ist'] = pd.to_datetime(trades['timestamp ist'], dayfirst=True, errors='coerce')
#       3 trades['date'] = trades['timestamp ist'].dt.date
#       5 trades.head()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4376 if self.columns.nlevels > 1:
#    4377     return self._getitem_multilevel(key)
# -> 4378 indexer = self.columns.get_loc(key)
#    4379 if is_integer(indexer):
#    4380     indexer = [indexer]
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'timestamp ist'
