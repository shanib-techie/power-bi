# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("irish_rent_by_county.xlsx")

print(df.describe())
print(df.info())

print(df["county"].equals(df["area"]))

print(df.head(10))
print(df.columns)
# Out:
#        Unnamed: 0    rent_euro         year        half  time_period  \
# count    286.0000   286.000000   286.000000  286.000000   286.000000
# mean     142.5000  1042.635979  2022.272727    1.454545     6.000000
# std       82.7053   298.337859     1.603425    0.498802     3.167821
# min        0.0000   574.130000  2020.000000    1.000000     1.000000
# 25%       71.2500   822.395000  2021.000000    1.000000     3.000000
# 50%      142.5000   989.245000  2022.000000    1.000000     6.000000
# 75%      213.7500  1196.610000  2024.000000    2.000000     9.000000
# max      285.0000  2147.300000  2025.000000    2.000000    11.000000
#
#        bedrooms_num
# count           0.0
# mean            NaN
# std             NaN
# min             NaN
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max             NaN
# <class 'pandas.DataFrame'>
# RangeIndex: 286 entries, 0 to 285
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ...

# %%
# ================================MAIN WORK ============================

# area wise property and its type and its and rent
# area_wise_province_mean_rent = df.groupby(["area","province"])["rent_euro"].mean()
# print(area_wise_province_mean_rent)

# area_wise_province_mean_rent_max = df.groupby(["area"]).agg(
#     max_rent=("rent_euro","max"),
#     mean_rent=("rent_euro","mean"),
#     count_property=("province","count")
# )
# print(area_wise_province_mean_rent_max)

# ==================type of properties in all areas======================

# area_province_count = df.groupby("area")["province"].value_counts()
# print(area_province_count)

print(df[["area","province"]].value_counts())
# Out:
# area       province
# Carlow     Leinster    11
# Cavan      Ulster      11
# Clare      Munster     11
# Cork       Munster     11
# Donegal    Ulster      11
# Dublin     Leinster    11
# Galway     Connacht    11
# Kerry      Munster     11
# Kildare    Leinster    11
# Kilkenny   Leinster    11
# Laois      Leinster    11
# Leitrim    Connacht    11
# Limerick   Munster     11
# Longford   Leinster    11
# Louth      Leinster    11
# Mayo       Connacht    11
# Meath      Leinster    11
# Monaghan   Ulster      11
# Offaly     Leinster    11
# Roscommon  Connacht    11
# Sligo      Connacht    11
# Tipperary  Munster     11
# Waterford  Munster     11
# Westmeath  Leinster    11
# Wexford    Leinster    11
# Wicklow    Leinster    11
# Name: count, dtype: int64
